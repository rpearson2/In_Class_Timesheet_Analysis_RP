# %% [markdown]
# # In class Assignment-
# Analyzing your `time sheet` using Pandas, Matplotlib and Seaborn modules.Save this file as InClassAssignment_Timesheet_xxxx where xxxx will be your initials
# - Name: Robert Pearson
# - Date: 2/15/2024
# - Version: 1

# %% [markdown]
# ### Import Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the dataset and save it to a dataframe named 'df'
# ![image.png](attachment:image.png)

# %%
df=pd.read_csv("Spring_Semester_Data2.csv")

# %% [markdown]
# ### Investigate your dataset (head, tail, info)
# - How many entries in your dataset?
# - Is there any missing value?
# - What are the data types?

# %% [markdown]
# I had 110 entries, there were no missing values, and my data types were objects and intergers. Total of 5 subjects. I had 29 entries for math-118, 24 for econ-111, 23 for math-205, 21 for busa-103, and 13 for ds-160.

# %%
df.head()
# Out:
#   Initial       Date    course_id  time(m)  \
# 0       RP  1/8/2024  ECON-111-02       50
# 1       RP  1/8/2024  MATH-118-01       50
# 2       RP  1/8/2024  MATH-205-03       75
# 3       RP  1/8/2024  BUSA-103-01       30
# 4       RP  1/9/2024  BUSA-103-01       75
#
#                                              Summary
# 0  Class - went over chapter 1 of economics textbook
# 1  Class - went of chapter 5.1 and 5.2 from Calcu...
# 2  Class - went over different types of data and ...
# 3    Read Chapter 1 of text book for quiz on Tuesday
# 4  Class - went over chapter 1 of the textbook an...

# %%
df.tail()
# Out:
#     Initial        Date    course_id  time(m)  \
# 105       RP  2/14/2024  ECON-111-02       50
# 106       RP  2/14/2024  BUSA-103-01       20
# 107       RP  2/14/2024  MATH-118-01       50
# 108       RP  2/14/2024  MATH-205-03       40
# 109       RP  2/14/2024  MATH-118-01       35
#
#                                              Summary
# 105  Class - Got exam back and had time to review it
# 106              Started work on partner presenation
# 107         Class - learned about improper integrals
# 108         Class - took individual part of the exam
# 109              Worked on practice problems for 7.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Initial    110 non-null    object
#  1   Date       110 non-null    object
#  2   course_id  110 non-null    object
#  3   time(m)    110 non-null    int64
#  4   Summary    110 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.4+ KB

# %%
df['course_id'].value_counts()
# Out:
# MATH-118-01    29
# ECON-111-02    24
# MATH-205-03    23
# BUSA-103-01    21
# DS-160-01      13
# Name: course_id, dtype: int64

# %% [markdown]
# ### Summary Statistics
# Calculate basic statistics for the 'Time (minutes)' column, such as mean, median, minimum, and maximum. This will give you an overview of how time is distributed across activities. use table and graphical representations (sample below)
# ![image.png](attachment:image.png)

# %% [markdown]
# The mean of time(m) is 58.97 minutes, the minimum time was 5 minutues, the maximum was 210 minutes, and the median was 50 minutes.

# %%
df.describe()
# Out:
#           time(m)
# count  110.000000
# mean    58.972727
# std     33.226622
# min      5.000000
# 25%     45.000000
# 50%     50.000000
# 75%     75.000000
# max    210.000000

# %%
df['time(m)'].median()
# Out:
# 50.0

# %%
sns.boxplot(x='course_id',
           y="time(m)",
            data=df)
plt.show()

# %% [markdown]
# ### Create two new columns "day" and "day_name" using the "Date" column in which the day will represent the range of days (sample below)
# ![image-2.png](attachment:image-2.png)
# - df['day'] = range(1, len(df) + 1)

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df['day_name']= df['Date'].dt.day_name()

# %%
df.head()
# Out:
#   Initial        Date    course_id  time(m)  \
# 0       RP 2024-01-08  ECON-111-02       50
# 1       RP 2024-01-08  MATH-118-01       50
# 2       RP 2024-01-08  MATH-205-03       75
# 3       RP 2024-01-08  BUSA-103-01       30
# 4       RP 2024-01-09  BUSA-103-01       75
#
#                                              Summary day_name
# 0  Class - went over chapter 1 of economics textbook   Monday
# 1  Class - went of chapter 5.1 and 5.2 from Calcu...   Monday
# 2  Class - went over different types of data and ...   Monday
# 3    Read Chapter 1 of text book for quiz on Tuesday   Monday
# 4  Class - went over chapter 1 of the textbook an...  Tuesday

# %%
df['day'] = range(1, len(df) + 1)

# %%
df.head()
# Out:
#   Initial        Date    course_id  time(m)  \
# 0       RP 2024-01-08  ECON-111-02       50
# 1       RP 2024-01-08  MATH-118-01       50
# 2       RP 2024-01-08  MATH-205-03       75
# 3       RP 2024-01-08  BUSA-103-01       30
# 4       RP 2024-01-09  BUSA-103-01       75
#
#                                              Summary day_name  day
# 0  Class - went over chapter 1 of economics textbook   Monday    1
# 1  Class - went of chapter 5.1 and 5.2 from Calcu...   Monday    2
# 2  Class - went over different types of data and ...   Monday    3
# 3    Read Chapter 1 of text book for quiz on Tuesday   Monday    4
# 4  Class - went over chapter 1 of the textbook an...  Tuesday    5

# %%
df.tail()
# Out:
#     Initial        Date    course_id  time(m)  \
# 105       RP 2024-02-14  ECON-111-02       50
# 106       RP 2024-02-14  BUSA-103-01       20
# 107       RP 2024-02-14  MATH-118-01       50
# 108       RP 2024-02-14  MATH-205-03       40
# 109       RP 2024-02-14  MATH-118-01       35
#
#                                              Summary   day_name  day
# 105  Class - Got exam back and had time to review it  Wednesday  106
# 106              Started work on partner presenation  Wednesday  107
# 107         Class - learned about improper integrals  Wednesday  108
# 108         Class - took individual part of the exam  Wednesday  109
# 109              Worked on practice problems for 7.8  Wednesday  110

# %% [markdown]
# ### Data Visualization:
# 1. Create a histogram to visually represent the distribution of time spent.
# 2. Create a  bar chart (sample below) to visually represent the distribution of time spent on different courses and comment on the course you spent most and least time
# ![image-3.png](attachment:image-3.png)

# %%
sns.histplot(x='time(m)', data=df)
plt.show()

# %%
sns.barplot(x='course_id', y='time(m)', ci=None, data=df)
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_28840\1106015526.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='course_id', y='time(m)', ci=None, data=df)
# <Axes: xlabel='course_id', ylabel='time(m)'>

# %%
df.groupby(['course_id'])['time(m)'].sum().plot(kind='bar')
plt.show()

# %% [markdown]
# Based off of the average time spent on a class, I spent the most time on MATH-205(around 68 minutes) and the least time on ECON-111(around 43 minutes).
#
# Based off of the total sum of time spent on a class, I spend the most time on Math-118(around 1875 minutes) and the least time on DS-160 (around 780 minutes).

# %% [markdown]
# ### Activity Counts:
#
# Count the occurrences of each course in the dataset to see `how often` you engaged in each.

# %%
df['course_id'].value_counts()
# Out:
# MATH-118-01    29
# ECON-111-02    24
# MATH-205-03    23
# BUSA-103-01    21
# DS-160-01      13
# Name: course_id, dtype: int64

# %% [markdown]
# I enganged in MATH-118 29 times, ECON-111 24 times, MATH-205 23 times, BUSA-103 21 times, and DS-160 13 times.

# %% [markdown]
# ### Time Trends:
#
# Plot a line chart (sample below) to visualize how time spent on activities changes over the observed days.
# ![image.png](attachment:image.png)

# %%
sns.lineplot(x='day', y='time(m)', hue='course_id', data=df)
plt.show()

# %% [markdown]
# The trend for mine is all over the place.

# %% [markdown]
# ### Course Analysis:
#
# For each course ex.(DS 160, CS 150, CS 440), calculate the total time spent. Which course received the most time, and which received the least?
# - Sample print statement: Total time spent on CS160: 180 min

# %%
df.groupby(['course_id'])['time(m)'].sum()
# Out:
# course_id
# BUSA-103-01    1181
# DS-160-01       805
# ECON-111-02    1028
# MATH-118-01    1878
# MATH-205-03    1595
# Name: time(m), dtype: int64

# %%
print('Total time spent on BUSA-103: 1181 min')
# Out:
# Total time spent on BUSA-103: 1181 min

# %%
print('Total time spent on DS-160: 805 min')
# Out:
# Total time spent on DS-160: 805 min

# %%
print('Total time spent on ECON-111: 1028 min')
# Out:
# Total time spent| on ECON-111: 1028 min

# %%
print('Total time spent on MATH-118: 1878 min')
# Out:
# Total time spent on MATH-118: 1878 min

# %%
print('Total time spent on MATH-205: 1595 min')
# Out:
# Total time spent on MATH-205: 1595 min

# %% [markdown]
# MATH-118 had the most time spent with 1878 minutes, while DS-160 had the least time spent with 805 minutes

# %% [markdown]
# ### Correlations:
# - Examine whether there are any correlations between the day and the time spent. For example, do you spend more time on courses over days or less (sample below).
# ![image.png](attachment:image.png)

# %%
corr=df[['day', 'time(m)' ]].corr()
print(corr)

sns.heatmap(corr, annot=True)
plt.show()
# Out:
#               day   time(m)
# day      1.000000  0.037684
# time(m)  0.037684  1.000000

# %% [markdown]
# The correlation doesn't represent the data well due to day being a count. It shows a correlation of 3.8% between the day(count) and time(m) which would be considered very weak with little to no correlation.

# %% [markdown]
# ### Your Reflection on the findings

# %% [markdown]
# From my findings, I found that I spend the most total time on MATH-118 with 1878 minutes. I spent the least amount of time on DS-160 with 805 minutes. My other classes I spent a total time of 1181 minutes on BUSA-103, 1028 minutes on ECON-111, and 1595 minutes on MATH-205. It seems the more frequent the class meets the more time I spend on it.
#
# When looking at the average time I spent on a class, the results were a different with the class with the greatest average time was MATH-205(around 68 minutes) and the least time on ECON-111(around 43 minutes). My other classes were, DS-160 with an average time spent around 62 minutes, MATH-118 around 65 minutes, and BUSA-103 around 56 minutes.
#
# I had 110 entries, there were no missing values, and my data types were objects and intergers. Total of 5 subjects. I had 29 entries for math-118, 24 for econ-111, 23 for math-205, 21 for busa-103, and 13 for ds-160. The mean of time(m) is 58.97 minutes, the minimum time was 5 minutues, the maximum was 210 minutes, and the median was 50 minutes. This result is also seen in the histogram of time(m), where it displays a right skew with outliers with past the 100 mark.

# %% [markdown]
# ### Submit the work by Friday 16th end of the day
